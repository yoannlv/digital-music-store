# %% [markdown]
# # P2. Les vues SQL

# %% [markdown]
# ## Définition d'une vue SQL
#
# Une vue n'est rien de plus qu'une instruction SQLite qui est stockée dans la base de données avec un nom associé. Il s'agit en fait d'une composition d'une table sous la forme d'une requête SQLite prédéfinie.
#
# Une vue peut contenir toutes les lignes d'une table ou des lignes sélectionnées d'une ou plusieurs tables. Une vue peut être créée à partir d'une ou plusieurs tables qui dépendent de la requête SQLite écrite pour créer une vue.

# %% [markdown]
# ## Code utilitaire

# %%
import os
import sqlite3
import pandas as pd

# %%
from pathlib import Path

# %%
# Ouvre connection vers SQLite db
chemin_bdd = Path('db') / 'chinook.db'
conn = sqlite3.connect(chemin_bdd)

# %%
# Fonction permettant d'exécuter un requête SQL sur une BDD définie par sa connexion conn
def executer_requete(requete_sql, conn):
    try:
        cursor = conn.cursor()
        cursor.execute(requete_sql)
        conn.commit()
    except sqlite3.Error as e:
        print("Erreur lors de l'execution de la requête")
        print(e)
        return
    cursor.close()

# %% [markdown]
# ## Example de vue SQL: v_albums

# %% [markdown]
# La requête suivante permet d'obtenir une liste (simplifiée) des albums / artistes correspondants:

# %%
# Requete sur les tables albums & artists
requete = """
    SELECT AlbumId,
           Title,
           a.Name AS Artist
    FROM albums
    JOIN artists a on albums.ArtistId = a.ArtistId
    ORDER BY Artist;
"""

albums = pd.read_sql_query(requete, conn)
albums.head(5)
# Out:
#    AlbumId                                  Title  \
# 0        1  For Those About To Rock We Salute You
# 1        4                      Let There Be Rock
# 2      296          A Copland Celebration, Vol. I
# 3      267                                 Worlds
# 4      280      The World of Classical Favourites
#
#                                               Artist
# 0                                              AC/DC
# 1                                              AC/DC
# 2          Aaron Copland & London Symphony Orchestra
# 3                                     Aaron Goldberg
# 4  Academy of St. Martin in the Fields & Sir Nevi...

# %% [markdown]
# Le code ci-dessous permet de créer une vue correspondant à la requête ci-dessous :
# Référence vue sous SQLite : https://www.sqlite.org/lang_createview.html

# %%
# creation vue albums avec artistes
creation_vue_albums = """
    CREATE VIEW v_albums (
        AlbumId,
        Title,
        Artist)
    AS
        SELECT AlbumId,
               Title,
               a.Name AS Artist
        FROM albums
        JOIN artists a on albums.ArtistId = a.ArtistId
        ORDER BY Artist, Title;
"""

executer_requete(creation_vue_albums, conn)
# Out:
# Erreur lors de l'execution de la requête
# table v_albums already exists

# %% [markdown]
# Une fois la vue créé, on peut la réutiliser dans des requêtes SQL comme une table:

# %%
# Utilisation de la vue v_albums
albums = pd.read_sql_query("SELECT * FROM v_albums LIMIT 10;", conn)
albums.head(5)
# Out:
#    AlbumId                                  Title     Artist          Time  \
# 0        1  For Those About To Rock We Salute You      AC/DC  144024900000
# 1        2                      Balls to the Wall     Accept   20553720000
# 2        3                      Restless and Wild     Accept   51485280000
# 3        4                      Let There Be Rock      AC/DC  147195540000
# 4        5                               Big Ones  Aerosmith  264702540000
#
#    Price
# 0   9.90
# 1   0.99
# 2   2.97
# 3   7.92
# 4  14.85

# %%
# Utilisation de la vue v_albums avec une clause WHERE
albums = pd.read_sql_query("SELECT * FROM v_albums WHERE Artist = 'U2';", conn)
albums
# Out:
#    AlbumId                                              Title Artist  \
# 0      232                                       Achtung Baby     U2
# 1      233                    All That You Can't Leave Behind     U2
# 2      234                                  B-Sides 1980-1990     U2
# 3      235                    How To Dismantle An Atomic Bomb     U2
# 4      236                                                Pop     U2
# 5      237                                     Rattle And Hum     U2
# 6      238                              The Best Of 1980-1990     U2
# 7      239                                                War     U2
# 8      240                                            Zooropa     U2
# 9      255  Instant Karma: The Amnesty International Campa...     U2
#
#            Time  Price
# 0  199709340000  11.88
# 1  177876240000  10.89
# 2  215693100000  14.85
# 3  176961060000  10.89
# 4  216754320000  11.88
# 5  260887560000  16.83
# 6  236154960000  13.86
# 7  151794180000   9.90
# 8  181395060000   9.90
# 9  308093160000  22.77

# %%
# Utilisation de la vue v_albums avec une autre jointure
requete = """
    SELECT a.AlbumId,
           a.Title,
           a.Artist,
           count(t.TrackId) as Tracks
    FROM v_albums a
    JOIN tracks t ON a.AlbumId = t.AlbumId
    GROUP BY 1, 2, 3
    ORDER BY 3, 2;
"""
albums = pd.read_sql_query(requete, conn)
albums.head()
# Out:
#    AlbumId                                  Title  \
# 0        1  For Those About To Rock We Salute You
# 1        4                      Let There Be Rock
# 2      296          A Copland Celebration, Vol. I
# 3      267                                 Worlds
# 4      280      The World of Classical Favourites
#
#                                               Artist  Tracks
# 0                                              AC/DC      10
# 1                                              AC/DC       8
# 2          Aaron Copland & London Symphony Orchestra       1
# 3                                     Aaron Goldberg       1
# 4  Academy of St. Martin in the Fields & Sir Nevi...       2

# %%
# Effacer une vue
executer_requete("DROP VIEW IF EXISTS v_albums;", conn)

# %% [markdown]
# ### Question: Avantages & Inconvénients des vues SQL

# %% [markdown]
# Quelles sont les avantages et inconvénients des vues SQL ?
#
# *Avantages :*
#
# - Gain de temps en cas de nombreuses utilisations d'une information
# - Simplification de la complexité des requêtes
#
# *Inconvénients :*
#
# - Ralentissement des performances des requêtes
# - A actualiser en cas de modification des données dans la BDD existante

# %% [markdown]
# ---

# %% [markdown]
# ## Exercices de création / mise en oeuvre de vues

# %% [markdown]
# ### Vue 1: caractéristiques complètes des Albums
# A partir de l'exemple de vue ci-dessus, créer et exploiter une nouvelle vue v_albums reprenant pour chaque album:
# - AlbumId
# - Title
# - Artist
# - nb de pistes
# - Durée totale de l'album (en minutes)
# - Prix de l'album

# %%
creation_v_albums = """
    CREATE VIEW v_albums (
        AlbumId,
        Title,
        Artist,
        Time,
        Price)
    AS
        SELECT albums.AlbumId,
        albums.Title,
        artists.Name,
        SUM(Milliseconds)*60000,
        SUM(tracks.UnitPrice)
        FROM albums
        JOIN artists ON albums.ArtistId = artists.ArtistId
        JOIN tracks ON albums.AlbumId = tracks.AlbumId
        GROUP BY albums.AlbumId
"""

executer_requete(creation_v_albums, conn)

# %%
albums2 = pd.read_sql_query("SELECT * FROM v_albums;", conn)
albums2
# Out:
#      AlbumId                                              Title  \
# 0          1              For Those About To Rock We Salute You
# 1          2                                  Balls to the Wall
# 2          3                                  Restless and Wild
# 3          4                                  Let There Be Rock
# 4          5                                           Big Ones
# ..       ...                                                ...
# 342      343                             Respighi:Pines of Rome
# 343      344  Schubert: The Late String Quartets & String Qu...
# 344      345                                Monteverdi: L'Orfeo
# 345      346                              Mozart: Chamber Music
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...
#
#                                                 Artist          Time  Price
# 0                                                AC/DC  144024900000   9.90
# 1                                               Accept   20553720000   0.99
# 2                                               Accept   51485280000   2.97
# 3                                                AC/DC  147195540000   7.92
# 4                                            Aerosmith  264702540000  14.85
# ..                                                 ...           ...    ...
# 342                                     Eugene Ormandy   17204460000   0.99
# 343                             Emerson String Quartet    8352000000   0.99
# 344  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...    3998340000   0.99
# 345                                      Nash Ensemble   13279860000   0.99
# 346                              Philip Glass Ensemble   12360300000   0.99
#
# [347 rows x 5 columns]

# %%
executer_requete("DROP VIEW IF EXISTS v_tracks;", conn)

# %%
creation_v_tracks = """
    CREATE VIEW v_tracks (
        TrackId,
        Name,
        Genre,
        Album,
        Artist,
        Composer,
        Time,
        MediaType
        )
    AS
        SELECT tracks.TrackId,
        tracks.Name,
        genres.Name,
        albums.Title,
        artists.Name,
        tracks.Composer,
        (tracks.Milliseconds)*1000,
        media_types.Name
        FROM tracks
        JOIN albums ON tracks.AlbumId = albums.AlbumId
        JOIN artists ON albums.ArtistId = artists.ArtistId
        JOIN genres ON tracks.GenreId = genres.GenreId
        JOIN media_types ON tracks.MediaTypeId = media_types.MediaTypeId
        """

executer_requete(creation_v_tracks, conn)

# %%
tracks = pd.read_sql_query("SELECT * FROM v_tracks;", conn)
tracks
# Out:
#       TrackId                                               Name       Genre  \
# 0           1            For Those About To Rock (We Salute You)        Rock
# 1           6                              Put The Finger On You        Rock
# 2           7                                    Let's Get It Up        Rock
# 3           8                                   Inject The Venom        Rock
# 4           9                                         Snowballed        Rock
# ...       ...                                                ...         ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...   Classical
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...   Classical
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)   Classical
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...   Classical
# 3502     3503                                      Koyaanisqatsi  Soundtrack
#
#                                                   Album  \
# 0                 For Those About To Rock We Salute You
# 1                 For Those About To Rock We Salute You
# 2                 For Those About To Rock We Salute You
# 3                 For Those About To Rock We Salute You
# 4                 For Those About To Rock We Salute You
# ...                                                 ...
# 3498                             Respighi:Pines of Rome
# 3499  Schubert: The Late String Quartets & String Qu...
# 3500                                Monteverdi: L'Orfeo
# 3501                              Mozart: Chamber Music
# 3502  Koyaanisqatsi (Soundtrack from the Motion Pict...
#
#                                                  Artist  \
# 0                                                 AC/DC
# 1                                                 AC/DC
# 2                                                 AC/DC
# 3                                                 AC/DC
# 4                                                 AC/DC
# ...                                                 ...
# 3498                                     Eugene Ormandy
# 3499                             Emerson String Quartet
# 3500  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 3501                                      Nash Ensemble
# 3502                              Philip Glass Ensemble
#
#                                        Composer       Time  \
# 0     Angus Young, Malcolm Young, Brian Johnson  343719000
# 1     Angus Young, Malcolm Young, Brian Johnson  205662000
# 2     Angus Young, Malcolm Young, Brian Johnson  233926000
# 3     Angus Young, Malcolm Young, Brian Johnson  210834000
# 4     Angus Young, Malcolm Young, Brian Johnson  203102000
# ...                                         ...        ...
# 3498                                       None  286741000
# 3499                             Franz Schubert  139200000
# 3500                         Claudio Monteverdi   66639000
# 3501                    Wolfgang Amadeus Mozart  221331000
# 3502                               Philip Glass  206005000
#
#                      MediaType
# 0              MPEG audio file
# 1              MPEG audio file
# 2              MPEG audio file
# 3              MPEG audio file
# 4              MPEG audio file
# ...                        ...
# 3498  Protected AAC audio file
# 3499  Protected AAC audio file
# 3500  Protected AAC audio file
# 3501  Protected AAC audio file
# 3502  Protected AAC audio file
#
# [3503 rows x 8 columns]

# %% [markdown]
# ### Vue 3: Vue augmentée invoices
# A. Créer une nouvelle vue v_invoices à partir de la table invoices ajoutant 3 nouveaux attributs basés sur l'attribut `InvoiceDate`:
# - semaine de la transaction
# - mois de la transaction
# - année de la transaction

# %%
executer_requete("DROP VIEW IF EXISTS v_invoices;", conn)

# %%
creation_v_invoices = """
    CREATE VIEW v_invoices (
        InvoiceId,
        CustomerId,
        InvoiceWeek,
        InvoiceMonth,
        InvoiceYear,
        BillingAddress,
        BillingCity,
        BillingState,
        BillingCountry,
        BillingPostalCode,
        Total)
    AS
        SELECT InvoiceId,
            CustomerId,
            STRFTIME("%W", InvoiceDate),
            STRFTIME("%M", InvoiceDate),
            STRFTIME("%Y", InvoiceDate),
            BillingAddress,
            BillingCity,
            BillingState,
            BillingCountry,
            BillingPostalCode,
            Total
        FROM invoices
    """

executer_requete(creation_v_invoices, conn)

# %%
v_invoices = pd.read_sql_query("SELECT * FROM v_invoices;", conn)
v_invoices
# Out:
#      InvoiceId  CustomerId InvoiceWeek InvoiceMonth InvoiceYear  \
# 0            1           2          00           00        2009
# 1            2           4          00           00        2009
# 2            3           8          00           00        2009
# 3            4          14          01           00        2009
# 4            5          23          01           00        2009
# ..         ...         ...         ...          ...         ...
# 407        408          25          48           00        2013
# 408        409          29          48           00        2013
# 409        410          35          49           00        2013
# 410        411          44          49           00        2013
# 411        412          58          50           00        2013
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart         None
# 1                            Ullevålsveien 14        Oslo         None
# 2                             Grétrystraat 63    Brussels         None
# 3                              8210 111 ST NW    Edmonton           AB
# 4                             69 Salem Street      Boston           MA
# ..                                        ...         ...          ...
# 407                     319 N. Frances Street     Madison           WI
# 408                    796 Dundas Street West     Toronto           ON
# 409  Rua dos Campeões Europeus de Viena, 4350       Porto         None
# 410                           Porthaninkatu 9    Helsinki         None
# 411                       12,Community Centre       Delhi         None
#
#     BillingCountry BillingPostalCode  Total
# 0          Germany             70174   1.98
# 1           Norway              0171   3.96
# 2          Belgium              1000   5.94
# 3           Canada           T6G 2C7   8.91
# 4              USA              2113  13.86
# ..             ...               ...    ...
# 407            USA             53703   3.96
# 408         Canada           M6J 1V1   5.94
# 409       Portugal              None   8.91
# 410        Finland             00530  13.86
# 411          India            110017   1.99
#
# [412 rows x 11 columns]

# %% [markdown]
# B. Exploiter la vue v_invoices ainsi crée pour déterminer les ventes annuelles par pays.

# %%
query3B = """
    SELECT DISTINCT BillingCountry AS "Pays", nine.Ventes AS "Ventes 2009", ten.Ventes AS "Ventes 2010", eleven.Ventes AS "Ventes 2011", twelve.Ventes AS "Ventes 2012", thirteen.Ventes AS "Vente 2013"
    FROM v_invoices
    
    LEFT JOIN
    (SELECT BillingCountry AS "Pays", SUM(Total) AS "Ventes"
    FROM v_invoices
    WHERE InvoiceYear = "2009"
    GROUP BY BillingCountry) AS nine
    ON v_invoices.BillingCountry = nine.Pays
    
    LEFT JOIN 
    (SELECT BillingCountry AS "Pays", SUM(Total) AS "Ventes"
    FROM v_invoices 
    WHERE InvoiceYear = "2010"
    GROUP BY BillingCountry) AS ten
    ON v_invoices.BillingCountry = ten.Pays
    
    LEFT JOIN
    (SELECT BillingCountry AS "Pays", SUM(Total) AS "Ventes"
    FROM v_invoices 
    WHERE InvoiceYear = "2011"
    GROUP BY BillingCountry) AS eleven
    ON v_invoices.BillingCountry = eleven.Pays
    
    LEFT JOIN
    (SELECT BillingCountry AS "Pays", SUM(Total) AS "Ventes"
    FROM v_invoices 
    WHERE InvoiceYear = "2012"
    GROUP BY BillingCountry) AS twelve
    ON v_invoices.BillingCountry = twelve.Pays
    
    LEFT JOIN
    (SELECT BillingCountry AS "Pays", SUM(Total) AS "Ventes"
    FROM v_invoices 
    WHERE InvoiceYear = "2013"
    GROUP BY BillingCountry) AS thirteen
    ON v_invoices.BillingCountry = thirteen.Pays
    
    ORDER BY "Pays"
"""

# %%
results = pd.read_sql_query(query3B, conn)
results
# Out:
#               Pays  Ventes 2009  Ventes 2010  Ventes 2011  Ventes 2012  \
# 0        Argentina          NaN        11.88         0.99          NaN
# 1        Australia        11.88         0.99         1.98        22.77
# 2          Austria         1.98        27.77          NaN        11.88
# 3          Belgium         6.93          NaN        24.75          NaN
# 4           Brazil        37.62        41.60        19.80        53.46
# 5           Canada        57.42        76.26        55.44        42.57
# 6            Chile        15.84        17.91         5.94         6.93
# 7   Czech Republic        10.89         9.90        12.87        19.83
# 8          Denmark         5.94         6.93          NaN        15.84
# 9          Finland         8.91          NaN        15.88         0.99
# 10          France        35.64        39.60        42.61        36.66
# 11         Germany        53.46        25.74        48.57        18.81
# 12         Hungary          NaN        32.75          NaN        11.88
# 13           India         9.90        17.83        24.75        10.89
# 14         Ireland         6.93          NaN        32.75          NaN
# 15           Italy         1.98        10.89          NaN        15.84
# 16     Netherlands         8.91         1.98        12.90         0.99
# 17          Norway        10.89          NaN        17.84         8.91
# 18          Poland        15.84         8.91          NaN        11.88
# 19        Portugal        11.88         6.93         8.91        24.77
# 20           Spain         0.99         1.98        22.77          NaN
# 21          Sweden         5.94         7.93          NaN        24.75
# 22             USA       103.95       102.98       103.01       127.98
# 23  United Kingdom        25.74        30.69        17.82         9.90
#
#     Vente 2013
# 0        24.75
# 1          NaN
# 2         0.99
# 3         5.94
# 4        37.62
# 5        72.27
# 6          NaN
# 7        36.75
# 8         8.91
# 9        15.84
# 10       40.59
# 11        9.90
# 12        0.99
# 13       11.89
# 14        5.94
# 15        8.91
# 16       15.84
# 17        1.98
# 18        0.99
# 19       24.75
# 20       11.88
# 21         NaN
# 22       85.14
# 23       28.71

# %% [markdown]
# ### Vue 4: A vous de jouer
# Créer et exploiter une nouvelle vue de votre choix

# %% [markdown]
# La vue suivante concerne la liste des clients pour laquelle nous avons également également ajouté l'employé référent. Cette vue nous permettra ensuite de connaître le nom de clients par employés sans avoir besoin de réaliser de jointures.

# %%
creation_v_customers = """
CREATE VIEW v_customers (
        CustomerId,
        Customer,
        Company,
        Address,
        City,
        State,
        Country,
        PostalCode,
        Phone,
        Fax,
        Email,
        EmployeeId,
        Employee)
    AS
		SELECT CustomerId,
			customers.firstname || ' ' || customers.lastname,
			customers.Company,
			customers.Address,
			customers.City,
			customers.State,
			customers.Country,
			customers.PostalCode,
			customers.Phone,
			customers.Fax,
			customers.Email,
            EmployeeId,
			employees.firstname || ' ' || employees.lastname
		FROM customers
		LEFT JOIN employees ON customers.SupportRepId = employees.EmployeeId
"""

executer_requete(creation_v_customers, conn)

# %%
v_customers = pd.read_sql_query("SELECT * FROM v_customers;", conn)
v_customers
# Out:
#     CustomerId               Customer  \
# 0            1         Luís Gonçalves
# 1            2          Leonie Köhler
# 2            3      François Tremblay
# 3            4           Bjørn Hansen
# 4            5  František Wichterlová
# 5            6            Helena Holý
# 6            7          Astrid Gruber
# 7            8           Daan Peeters
# 8            9           Kara Nielsen
# 9           10        Eduardo Martins
# 10          11        Alexandre Rocha
# 11          12        Roberto Almeida
# 12          13         Fernanda Ramos
# 13          14           Mark Philips
# 14          15      Jennifer Peterson
# 15          16           Frank Harris
# 16          17             Jack Smith
# 17          18        Michelle Brooks
# 18          19              Tim Goyer
# 19          20             Dan Miller
# 20          21            Kathy Chase
# 21          22        Heather Leacock
# 22          23            John Gordon
# 23          24          Frank Ralston
# 24          25         Victor Stevens
# 25          26     Richard Cunningham
# 26          27           Patrick Gray
# 27          28          Julia Barnett
# 28          29           Robert Brown
# 29          30         Edward Francis
# 30          31            Martha Silk
# 31          32         Aaron Mitchell
# 32          33         Ellie Sullivan
# 33          34         João Fernandes
# 34          35       Madalena Sampaio
# 35          36       Hannah Schneider
# 36          37        Fynn Zimmermann
# 37          38        Niklas Schröder
# 38          39        Camille Bernard
# 39          40     Dominique Lefebvre
# 40          41            Marc Dubois
# 41          42           Wyatt Girard
# 42          43       Isabelle Mercier
# 43          44       Terhi Hämäläinen
# 44          45        Ladislav Kovács
# 45          46          Hugh O'Reilly
# 46          47          Lucas Mancini
# 47          48  Johannes Van der Berg
# 48          49       Stanisław Wójcik
# 49          50          Enrique Muñoz
# 50          51       Joakim Johansson
# 51          52             Emma Jones
# 52          53            Phil Hughes
# 53          54           Steve Murray
# 54          55            Mark Taylor
# 55          56        Diego Gutiérrez
# 56          57             Luis Rojas
# 57          58           Manoj Pareek
# 58          59        Puja Srivastava
#
#                                              Company  \
# 0   Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                   JetBrains s.r.o.
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                   Woodstock Discos
# 10                              Banco do Brasil S.A.
# 11                                            Riotur
# 12                                              None
# 13                                             Telus
# 14                                     Rogers Canada
# 15                                       Google Inc.
# 16                             Microsoft Corporation
# 17                                              None
# 18                                        Apple Inc.
# 19                                              None
# 20                                              None
# 21                                              None
# 22                                              None
# 23                                              None
# 24                                              None
# 25                                              None
# 26                                              None
# 27                                              None
# 28                                              None
# 29                                              None
# 30                                              None
# 31                                              None
# 32                                              None
# 33                                              None
# 34                                              None
# 35                                              None
# 36                                              None
# 37                                              None
# 38                                              None
# 39                                              None
# 40                                              None
# 41                                              None
# 42                                              None
# 43                                              None
# 44                                              None
# 45                                              None
# 46                                              None
# 47                                              None
# 48                                              None
# 49                                              None
# 50                                              None
# 51                                              None
# 52                                              None
# 53                                              None
# 54                                              None
# 55                                              None
# 56                                              None
# 57                                              None
# 58                                              None
#
#                                      Address                 City   State  \
# 0            Av. Brigadeiro Faria Lima, 2170  São José dos Campos      SP
# 1                    Theodor-Heuss-Straße 34            Stuttgart    None
# 2                          1498 rue Bélanger             Montréal      QC
# 3                           Ullevålsveien 14                 Oslo    None
# 4                              Klanova 9/506               Prague    None
# 5                              Rilská 3174/6               Prague    None
# 6       Rotenturmstraße 4, 1010 Innere Stadt               Vienne    None
# 7                            Grétrystraat 63             Brussels    None
# 8                        Sønder Boulevard 51           Copenhagen    None
# 9                  Rua Dr. Falcão Filho, 155            São Paulo      SP
# 10                        Av. Paulista, 2022            São Paulo      SP
# 11                          Praça Pio X, 119       Rio de Janeiro      RJ
# 12                              Qe 7 Bloco G             Brasília      DF
# 13                            8210 111 ST NW             Edmonton      AB
# 14                       700 W Pender Street            Vancouver      BC
# 15                 1600 Amphitheatre Parkway        Mountain View      CA
# 16                           1 Microsoft Way              Redmond      WA
# 17                              627 Broadway             New York      NY
# 18                           1 Infinite Loop            Cupertino      CA
# 19                      541 Del Medio Avenue        Mountain View      CA
# 20                          801 W 4th Street                 Reno      NV
# 21                          120 S Orange Ave              Orlando      FL
# 22                           69 Salem Street               Boston      MA
# 23                     162 E Superior Street              Chicago      IL
# 24                     319 N. Frances Street              Madison      WI
# 25                       2211 W Berry Street           Fort Worth      TX
# 26                           1033 N Park Ave               Tucson      AZ
# 27                               302 S 700 E       Salt Lake City      UT
# 28                    796 Dundas Street West              Toronto      ON
# 29                          230 Elgin Street               Ottawa      ON
# 30                     194A Chain Lake Drive              Halifax      NS
# 31                        696 Osborne Street             Winnipeg      MB
# 32                            5112 48 Street          Yellowknife      NT
# 33                        Rua da Assunção 53               Lisbon    None
# 34  Rua dos Campeões Europeus de Viena, 4350                Porto    None
# 35                        Tauentzienstraße 8               Berlin    None
# 36                          Berger Straße 10            Frankfurt    None
# 37                       Barbarossastraße 19               Berlin    None
# 38                             4, Rue Milton                Paris    None
# 39                            8, Rue Hanovre                Paris    None
# 40                       11, Place Bellecour                 Lyon    None
# 41                    9, Place Louis Barthou             Bordeaux    None
# 42                          68, Rue Jouvence                Dijon    None
# 43                           Porthaninkatu 9             Helsinki    None
# 44                         Erzsébet krt. 58.             Budapest    None
# 45                          3 Chatham Street               Dublin  Dublin
# 46                    Via Degli Scipioni, 43                 Rome      RM
# 47                     Lijnbaansgracht 120bg            Amsterdam      VV
# 48                              Ordynacka 10               Warsaw    None
# 49                        C/ San Bernardo 85               Madrid    None
# 50                               Celsiusg. 9            Stockholm    None
# 51                         202 Hoxton Street               London    None
# 52                              113 Lupus St               London    None
# 53                            110 Raeburn Pl           Edinburgh     None
# 54                         421 Bourke Street               Sidney     NSW
# 55                        307 Macacha Güemes         Buenos Aires    None
# 56                           Calle Lira, 198             Santiago    None
# 57                       12,Community Centre                Delhi    None
# 58                         3,Raj Bhavan Road            Bangalore    None
#
#            Country  PostalCode                Phone                 Fax  \
# 0           Brazil   12227-000   +55 (12) 3923-5555  +55 (12) 3923-5566
# 1          Germany       70174     +49 0711 2842222                None
# 2           Canada     H2G 1A7    +1 (514) 721-4711                None
# 3           Norway        0171      +47 22 44 22 22                None
# 4   Czech Republic       14700     +420 2 4172 5555    +420 2 4172 5555
# 5   Czech Republic       14300     +420 2 4177 0449                None
# 6          Austria        1010       +43 01 5134505                None
# 7          Belgium        1000     +32 02 219 03 03                None
# 8          Denmark        1720       +453 3331 9991                None
# 9           Brazil   01007-010   +55 (11) 3033-5446  +55 (11) 3033-4564
# 10          Brazil   01310-200   +55 (11) 3055-3278  +55 (11) 3055-8131
# 11          Brazil   20040-020   +55 (21) 2271-7000  +55 (21) 2271-7070
# 12          Brazil   71020-677   +55 (61) 3363-5547  +55 (61) 3363-7855
# 13          Canada     T6G 2C7    +1 (780) 434-4554   +1 (780) 434-5565
# 14          Canada     V6C 1G8    +1 (604) 688-2255   +1 (604) 688-8756
# 15             USA  94043-1351    +1 (650) 253-0000   +1 (650) 253-0000
# 16             USA  98052-8300    +1 (425) 882-8080   +1 (425) 882-8081
# 17             USA  10012-2612    +1 (212) 221-3546   +1 (212) 221-4679
# 18             USA       95014    +1 (408) 996-1010   +1 (408) 996-1011
# 19             USA   94040-111    +1 (650) 644-3358                None
# 20             USA       89503    +1 (775) 223-7665                None
# 21             USA       32801    +1 (407) 999-7788                None
# 22             USA        2113    +1 (617) 522-1333                None
# 23             USA       60611    +1 (312) 332-3232                None
# 24             USA       53703    +1 (608) 257-0597                None
# 25             USA       76110    +1 (817) 924-7272                None
# 26             USA       85719    +1 (520) 622-4200                None
# 27             USA       84102    +1 (801) 531-7272                None
# 28          Canada     M6J 1V1    +1 (416) 363-8888                None
# 29          Canada     K2P 1L7    +1 (613) 234-3322                None
# 30          Canada     B3S 1C5    +1 (902) 450-0450                None
# 31          Canada     R3L 2B9    +1 (204) 452-6452                None
# 32          Canada     X1A 1N6    +1 (867) 920-2233                None
# 33        Portugal        None   +351 (213) 466-111                None
# 34        Portugal        None   +351 (225) 022-448                None
# 35         Germany       10789     +49 030 26550280                None
# 36         Germany       60316     +49 069 40598889                None
# 37         Germany       10779      +49 030 2141444                None
# 38          France       75009   +33 01 49 70 65 65                None
# 39          France       75002   +33 01 47 42 71 71                None
# 40          France       69002   +33 04 78 30 30 30                None
# 41          France       33000   +33 05 56 96 96 96                None
# 42          France       21000   +33 03 80 73 66 99                None
# 43         Finland       00530     +358 09 870 2000                None
# 44         Hungary      H-1073                 None                None
# 45         Ireland        None      +353 01 6792424                None
# 46           Italy       00192      +39 06 39733434                None
# 47     Netherlands        1016      +31 020 6223130                None
# 48          Poland      00-358     +48 22 828 37 39                None
# 49           Spain       28015      +34 914 454 454                None
# 50          Sweden       11230     +46 08-651 52 52                None
# 51  United Kingdom      N1 5LH    +44 020 7707 0707                None
# 52  United Kingdom    SW1V 3EN    +44 020 7976 5722                None
# 53  United Kingdom     EH4 1HH    +44 0131 315 3300                None
# 54       Australia        2010   +61 (02) 9332 3633                None
# 55       Argentina        1106  +54 (0)11 4311 4333                None
# 56           Chile        None    +56 (0)2 635 4444                None
# 57           India      110017    +91 0124 39883988                None
# 58           India      560001     +91 080 22289999                None
#
#                             Email  EmployeeId       Employee
# 0            luisg@embraer.com.br           3   Jane Peacock
# 1           leonekohler@surfeu.de           5  Steve Johnson
# 2             ftremblay@gmail.com           3   Jane Peacock
# 3           bjorn.hansen@yahoo.no           4  Margaret Park
# 4        frantisekw@jetbrains.com           4  Margaret Park
# 5                 hholy@gmail.com           5  Steve Johnson
# 6          astrid.gruber@apple.at           5  Steve Johnson
# 7           daan_peeters@apple.be           4  Margaret Park
# 8           kara.nielsen@jubii.dk           4  Margaret Park
# 9        eduardo@woodstock.com.br           4  Margaret Park
# 10               alero@uol.com.br           5  Steve Johnson
# 11  roberto.almeida@riotur.gov.br           3   Jane Peacock
# 12       fernadaramos4@uol.com.br           4  Margaret Park
# 13             mphilips12@shaw.ca           5  Steve Johnson
# 14            jenniferp@rogers.ca           3   Jane Peacock
# 15             fharris@google.com           4  Margaret Park
# 16        jacksmith@microsoft.com           5  Steve Johnson
# 17              michelleb@aol.com           3   Jane Peacock
# 18               tgoyer@apple.com           3   Jane Peacock
# 19            dmiller@comcast.com           4  Margaret Park
# 20            kachase@hotmail.com           5  Steve Johnson
# 21             hleacock@gmail.com           4  Margaret Park
# 22         johngordon22@yahoo.com           4  Margaret Park
# 23             fralston@gmail.com           3   Jane Peacock
# 24             vstevens@yahoo.com           5  Steve Johnson
# 25       ricunningham@hotmail.com           4  Margaret Park
# 26           patrick.gray@aol.com           4  Margaret Park
# 27            jubarnett@gmail.com           5  Steve Johnson
# 28               robbrown@shaw.ca           3   Jane Peacock
# 29            edfrancis@yachoo.ca           3   Jane Peacock
# 30           marthasilk@gmail.com           5  Steve Johnson
# 31         aaronmitchell@yahoo.ca           4  Margaret Park
# 32         ellie.sullivan@shaw.ca           3   Jane Peacock
# 33            jfernandes@yahoo.pt           4  Margaret Park
# 34              masampaio@sapo.pt           4  Margaret Park
# 35      hannah.schneider@yahoo.de           5  Steve Johnson
# 36           fzimmermann@yahoo.de           3   Jane Peacock
# 37            nschroder@surfeu.de           3   Jane Peacock
# 38       camille.bernard@yahoo.fr           4  Margaret Park
# 39    dominiquelefebvre@gmail.com           4  Margaret Park
# 40        marc.dubois@hotmail.com           5  Steve Johnson
# 41          wyatt.girard@yahoo.fr           3   Jane Peacock
# 42      isabelle_mercier@apple.fr           3   Jane Peacock
# 43      terhi.hamalainen@apple.fi           3   Jane Peacock
# 44       ladislav_kovacs@apple.hu           3   Jane Peacock
# 45           hughoreilly@apple.ie           3   Jane Peacock
# 46         lucas.mancini@yahoo.it           5  Steve Johnson
# 47        johavanderberg@yahoo.nl           5  Steve Johnson
# 48         stanisław.wójcik@wp.pl           4  Margaret Park
# 49         enrique_munoz@yahoo.es           5  Steve Johnson
# 50      joakim.johansson@yahoo.se           5  Steve Johnson
# 51         emma_jones@hotmail.com           3   Jane Peacock
# 52          phil.hughes@gmail.com           3   Jane Peacock
# 53          steve.murray@yahoo.uk           5  Steve Johnson
# 54           mark.taylor@yahoo.au           4  Margaret Park
# 55       diego.gutierrez@yahoo.ar           4  Margaret Park
# 56             luisrojas@yahoo.cl           5  Steve Johnson
# 57        manoj.pareek@rediff.com           3   Jane Peacock
# 58       puja_srivastava@yahoo.in           3   Jane Peacock

# %%
query4 = """
SELECT Employee, count(*) As "Nb clients"
FROM v_customers
GROUP BY EmployeeId"
